# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilshah9111/Data_Science/blob/main/Data_Sci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **PART 0: Reading the data**

# %%
data = pd.read_csv('Fytlyff_DS_Interview.csv')
data.head()
# Out:
#    Year Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019   Jan  Desktop_Website  Existing_Customer
# 1  2019   Jan  Desktop_Website  Existing_Customer
# 2  2019   Jan  Desktop_Website  Existing_Customer
# 3  2019   Jan  Desktop_Website  Existing_Customer
# 4  2019   Jan  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0             Came_From_Google             Bangalore
# 1             Came_From_Google               Chennai
# 2             Came_From_Google              Dehradun
# 3             Came_From_Google                Indore
# 4             Came_From_Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Year                                                                                                                       2160 non-null   int64
#  1   Month                                                                                                                      2160 non-null   object
#  2   MobileWeb_or_Web                                                                                                           2160 non-null   object
# ...

# %% [markdown]
# By using info method, we observe the column names along with the datatype of each column and find out the null values in each column.

# %%
data.shape #Checking the dimension of dataset
# Out:
# (2160, 10)

# %%
data.columns[data.isna().any()].tolist() #Finding which columns have null values
# Out:
# ['How_many_Landed_on_our_Page?',
#  'How_many_Landed_on_the_our_Page_and_clicked_on_a_button?']

# %% [markdown]
# **PART 1: Data Cleaning**

# %%
data.head()
# Out:
#    Year Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019   Jan  Desktop_Website  Existing_Customer
# 1  2019   Jan  Desktop_Website  Existing_Customer
# 2  2019   Jan  Desktop_Website  Existing_Customer
# 3  2019   Jan  Desktop_Website  Existing_Customer
# 4  2019   Jan  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0             Came_From_Google             Bangalore
# 1             Came_From_Google               Chennai
# 2             Came_From_Google              Dehradun
# 3             Came_From_Google                Indore
# 4             Came_From_Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                NaN
# ...

# %%
from time import strptime

def data_cleaning(df):
  df['How_many_Landed_on_our_Page?'] = df['How_many_Landed_on_our_Page?'].fillna(0)
  df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'] = df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'].fillna(0)
  df['Month'] = [strptime(str(x), '%b').tm_mon for x in df['Month']]
  df['Where_Are_They_comming_from?'] = df['Where_Are_They_comming_from?'].replace({'Came_From_Google':'Google', 'Landed_on_the_page_Directly':'Direct_traffic'})

# %%
data_cleaning(data)

# %%
data.head(10)
# Out:
#    Year  Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019      1  Desktop_Website  Existing_Customer
# 1  2019      1  Desktop_Website  Existing_Customer
# 2  2019      1  Desktop_Website  Existing_Customer
# 3  2019      1  Desktop_Website  Existing_Customer
# 4  2019      1  Desktop_Website  Existing_Customer
# 5  2019      1  Desktop_Website  Existing_Customer
# 6  2019      1  Desktop_Website  Existing_Customer
# 7  2019      1  Desktop_Website  Existing_Customer
# 8  2019      1  Desktop_Website  Existing_Customer
# 9  2019      1  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                       Google             Bangalore
# 1                       Google               Chennai
# 2                       Google              Dehradun
# 3                       Google                Indore
# 4                       Google                  Pune
# 5               Direct_traffic             Bangalore
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Year                                                                                                                       2160 non-null   int64
#  1   Month                                                                                                                      2160 non-null   int64
#  2   MobileWeb_or_Web                                                                                                           2160 non-null   object
# ...

# %% [markdown]
# As you can see there are no null values now, but we need to convert float datatype to int

# %%
data = data.astype({'How_many_Landed_on_our_Page?': 'int64', 'How_many_Landed_on_the_our_Page_and_clicked_on_a_button?': 'int64'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Year                                                                                                                       2160 non-null   int64
#  1   Month                                                                                                                      2160 non-null   int64
#  2   MobileWeb_or_Web                                                                                                           2160 non-null   object
# ...

# %%
data.head()
# Out:
#    Year  Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019      1  Desktop_Website  Existing_Customer
# 1  2019      1  Desktop_Website  Existing_Customer
# 2  2019      1  Desktop_Website  Existing_Customer
# 3  2019      1  Desktop_Website  Existing_Customer
# 4  2019      1  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                       Google             Bangalore
# 1                       Google               Chennai
# 2                       Google              Dehradun
# 3                       Google                Indore
# 4                       Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                  0
# ...

# %% [markdown]
# **PART 2: Descriptive Statistics**

# %%
from functools import partial

def descriptive_stats(data):
  q_25 = partial(pd.Series.quantile, q=0.25)
  q_25.__name__ = "25%"

  q_75 = partial(pd.Series.quantile, q=0.75)
  q_75.__name__ = "75%"

  print(data.agg(["mean", q_25, "median", q_75, "std"]),"\n")

  non_numerical = []
  for col in data:
    if data[col].dtypes != "int64":
      non_numerical.append(col)
  

  for col in non_numerical:
    print(data[col].unique())
    print(data[col].dtypes,'\n')

# %%
descriptive_stats(data)
# Out:
#                Year     Month  How_many_Landed_on_our_Page?  \
# mean    2020.000000  6.500000                 392247.442593
# 25%     2019.000000  3.750000                      0.000000
# median  2020.000000  6.500000                  12283.500000
# 75%     2021.000000  9.250000                 381642.250000
# std        0.816686  3.452852                 955577.328614
#
#         How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# mean                                        179228.131944
# 25%                                              0.000000
# median                                        4212.500000
# 75%                                         173045.250000
# std                                         395156.221812
#
#         How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?  \
# mean                                        151072.456019
# 25%                                          33608.000000
# ...

# %% [markdown]
# **PART 3: Prescriptive Statistics**

# %%
test = data.sort_values('How_many_Landed_on_our_Page?', ascending=False)
test[['Which_Place_in_India?', 'How_many_Landed_on_our_Page?']]
# Out:
#      Which_Place_in_India?  How_many_Landed_on_our_Page?
# 984                   Pune                      11274131
# 1764                  Pune                       9083552
# 2064                  Pune                       9036434
# 924                   Pune                       8949571
# 1284                  Pune                       8188402
# ...                    ...                           ...
# 943                 Indore                             0
# 942               Dehradun                             0
# 941                Chennai                             0
# 940              Bangalore                             0
# 1080             Bangalore                             0
#
# [2160 rows x 2 columns]

# %% [markdown]
# **So, as you can see Pune has the highest 'How_many_Landed_on_our_Page?'**

# %%
test1 = data.copy(deep=True)
test1['div'] = test1['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'] / test1['How_many_Landed_on_our_Page?']

# %%
test1.head()
# Out:
#    Year  Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019      1  Desktop_Website  Existing_Customer
# 1  2019      1  Desktop_Website  Existing_Customer
# 2  2019      1  Desktop_Website  Existing_Customer
# 3  2019      1  Desktop_Website  Existing_Customer
# 4  2019      1  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                       Google             Bangalore
# 1                       Google               Chennai
# 2                       Google              Dehradun
# 3                       Google                Indore
# 4                       Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                  0
# ...

# %% [markdown]
# **Newly formed column contains infinity values also, so I will replace infinity value with maximum value of this column.**

# %%
mask = test1['div'] != np.inf
test1.loc[~mask, 'div'] = test1.loc[mask, 'div'].max()

# %%
test1.head()
# Out:
#    Year  Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019      1  Desktop_Website  Existing_Customer
# 1  2019      1  Desktop_Website  Existing_Customer
# 2  2019      1  Desktop_Website  Existing_Customer
# 3  2019      1  Desktop_Website  Existing_Customer
# 4  2019      1  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                       Google             Bangalore
# 1                       Google               Chennai
# 2                       Google              Dehradun
# 3                       Google                Indore
# 4                       Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                  0
# ...

# %%
test1 = test1.sort_values('div', ascending=False)
test1[['Which_Place_in_India?', 'div']]
# Out:
#      Which_Place_in_India?       div
# 0                Bangalore  0.618404
# 1208                Indore  0.618404
# 1206               Chennai  0.618404
# 1205             Bangalore  0.618404
# 1204                  Pune  0.618404
# ...                    ...       ...
# 2095             Bangalore  0.018770
# 1222              Dehradun  0.018693
# 1769                  Pune  0.014943
# 2152              Dehradun  0.014933
# 2064                  Pune  0.013187
#
# [2160 rows x 2 columns]

# %% [markdown]
# **Bangalore has the highest**

# %% [markdown]
# **PART 4: Simple Machine Learning**

# %%
data.head()
# Out:
#    Year  Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019      1  Desktop_Website  Existing_Customer
# 1  2019      1  Desktop_Website  Existing_Customer
# 2  2019      1  Desktop_Website  Existing_Customer
# 3  2019      1  Desktop_Website  Existing_Customer
# 4  2019      1  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                       Google             Bangalore
# 1                       Google               Chennai
# 2                       Google              Dehradun
# 3                       Google                Indore
# 4                       Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                  0
# ...

# %%
tot = data.groupby(['Year','Month']).agg({'How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?': sum})
tot.head()
# Out:
#             How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# Year Month
# 2019 1                                                3589410
#      2                                                2717346
#      3                                                3322524
#      4                                                3508967
#      5                                                5260855

# %%
tot.reset_index(inplace=True)

# %%
tot = tot.astype({'Year':'str', 'Month':'str'})
tot['ds'] = pd.DatetimeIndex(tot['Year']+'-'+tot['Month'])
tot.head()
# Out:
#    Year Month  \
# 0  2019     1
# 1  2019     2
# 2  2019     3
# 3  2019     4
# 4  2019     5
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?  \
# 0                                            3589410
# 1                                            2717346
# 2                                            3322524
# 3                                            3508967
# 4                                            5260855
#
#           ds
# 0 2019-01-01
# 1 2019-02-01
# 2 2019-03-01
# 3 2019-04-01
# 4 2019-05-01

# %%
tot = tot.iloc[:,[0,1,3,2]]
tot.head()
# Out:
#    Year Month         ds  \
# 0  2019     1 2019-01-01
# 1  2019     2 2019-02-01
# 2  2019     3 2019-03-01
# 3  2019     4 2019-04-01
# 4  2019     5 2019-05-01
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# 0                                            3589410
# 1                                            2717346
# 2                                            3322524
# 3                                            3508967
# 4                                            5260855

# %%
tot = tot[['ds','How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?']]
tot.head()
# Out:
#           ds  \
# 0 2019-01-01
# 1 2019-02-01
# 2 2019-03-01
# 3 2019-04-01
# 4 2019-05-01
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# 0                                            3589410
# 1                                            2717346
# 2                                            3322524
# 3                                            3508967
# 4                                            5260855

# %%
#!pip install prophet

# %%
"""
from prophet import Prophet
from sklearn.metrics import mean_absolute_percentage_error

# prepare expected column names
tot.columns = ['ds', 'y']
tot['ds']= pd.to_datetime(tot['ds'])
# create test dataset, remove last 12 months
train = tot.drop(tot.index[-12:])
print(train.tail())
# define the model
model = Prophet()
# fit the model
model.fit(train)
# define the period for which we want a prediction
future21 = list()
for i in range(1, 13):
  date = '1968-%02d' % i
  future21.append([date])
future21 = pd.DataFrame(future21)
future21.columns = ['ds']
future21['ds'] = pd.to_datetime(future21['ds'])
print(future21)
# use the model to make a forecast
forecast = model.predict(future21)
print(forecast)
y_true = tot['y'][-12:].values
y_pred = forecast['yhat'].values
print(y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
print('MAPE: %.3f' % mape)
# plot expected vs actual
plt.plot(y_true, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()
"""
# Out:
# "\nfrom prophet import Prophet\nfrom sklearn.metrics import mean_absolute_percentage_error\n\n# prepare expected column names\ntot.columns = ['ds', 'y']\ntot['ds']= pd.to_datetime(tot['ds'])\n# create test dataset, remove last 12 months\ntrain = tot.drop(tot.index[-12:])\nprint(train.tail())\n# define the model\nmodel = Prophet()\n# fit the model\nmodel.fit(train)\n# define the period for which we want a prediction\nfuture21 = list()\nfor i in range(1, 13):\n  date = '1968-%02d' % i\n  future21.append([date])\nfuture21 = pd.DataFrame(future21)\nfuture21.columns = ['ds']\nfuture21['ds'] = pd.to_datetime(future21['ds'])\nprint(future21)\n# use the model to make a forecast\nforecast = model.predict(future21)\nprint(forecast)\ny_true = tot['y'][-12:].values\ny_pred = forecast['yhat'].values\nprint(y_pred)\nmape = mean_absolute_percentage_error(y_true, y_pred)\nprint('MAPE: %.3f' % mape)\n# plot expected vs actual\nplt.plot(y_true, label='Actual')\nplt.plot(y_pred, label='Predicted')\nplt
# ...

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 4.5 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 43.5 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# ...

# %%
tot.head()
# Out:
#           ds  \
# 0 2019-01-01
# 1 2019-02-01
# 2 2019-03-01
# 3 2019-04-01
# 4 2019-05-01
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# 0                                            3589410
# 1                                            2717346
# 2                                            3322524
# 3                                            3508967
# 4                                            5260855

# %%
tot = tot.set_index('ds')
tot.head()
# Out:
#             How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# ds
# 2019-01-01                                            3589410
# 2019-02-01                                            2717346
# 2019-03-01                                            3322524
# 2019-04-01                                            3508967
# 2019-05-01                                            5260855

# %%
tot['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression:", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
    print("\t",key, ": ", val)

# %%
ad_test(tot['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'])
# Out:
# 1. ADF :  -2.9896121136675826
# 2. P-Value :  0.035875952011252064
# 3. Num Of Lags :  1
# 4. Num Of Observations Used For ADF Regression: 34
# 5. Critical Values :
# 	 1% :  -3.639224104416853
# 	 5% :  -2.9512301791166293
# 	 10% :  -2.614446989619377

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings("ignore")

# %%
stepwise_fit = auto_arima(tot['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'], trace=True, suppress_warnings=True)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1072.005, Time=0.62 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1072.117, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1063.919, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1066.329, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1191.427, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1065.668, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1065.798, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1067.853, Time=0.30 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1075.669, Time=0.07 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.474 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   36
# ...

# %%
print(tot.shape)
train=tot.iloc[:-12]
test=tot.iloc[-12:]
print(train.shape,test.shape)
# Out:
# (36, 1)
# (24, 1) (12, 1)

# %%
from statsmodels.tsa.arima.model import ARIMA
model=ARIMA(train['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'],order=(1,0,0))
model=model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                                                    SARIMAX Results
# ...
# Dep. Variable:     How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?   No. Observations:                   24
# Model:                                                                                                                        ARIMA(1, 0, 0)   Log Likelihood                -355.433
# Date:                                                                                                                       Wed, 12 Oct 2022   AIC                            716.866
# Time:                                                                                                                               17:42:37   BIC                            720.400
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels').rename('ARIMA Predictions')
print(pred)
# Out:
# 2021-01-01    3.166692e+06
# 2021-02-01    3.437204e+06
# 2021-03-01    3.547559e+06
# 2021-04-01    3.592578e+06
# 2021-05-01    3.610943e+06
# 2021-06-01    3.618436e+06
# 2021-07-01    3.621492e+06
# 2021-08-01    3.622739e+06
# 2021-09-01    3.623248e+06
# 2021-10-01    3.623455e+06
# 2021-11-01    3.623540e+06
# 2021-12-01    3.623574e+06
# Freq: MS, Name: ARIMA Predictions, dtype: float64

# %%
pred.plot(legend=True)
test['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'].plot(legend=True)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(test['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'], pred)
print(mape)
# Out:
# 0.13754375933904298

# %%
model2 = ARIMA(tot['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'], order=(1,0,0))
model2 = model2.fit()
tot.tail()
# Out:
#             How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?
# ds
# 2021-08-01                                            3959670
# 2021-09-01                                            3434896
# 2021-10-01                                            3673751
# 2021-11-01                                            4072884
# 2021-12-01                                            4189930

# %%
d = pd.date_range(start='1/1/2022', end='12/1/2022', freq='MS')    
index_future_dates = pd.date_range(start='1/1/2022', end='12/1/2022', freq='MS')
pred = model2.predict(start=len(tot),end=len(tot)+11,typ='levels').rename('ARIMA Predictions')
print(pred)
# Out:
# 2022-01-01    3.868509e+06
# 2022-02-01    3.709361e+06
# 2022-03-01    3.630560e+06
# 2022-04-01    3.591543e+06
# 2022-05-01    3.572224e+06
# 2022-06-01    3.562659e+06
# 2022-07-01    3.557923e+06
# 2022-08-01    3.555577e+06
# 2022-09-01    3.554416e+06
# 2022-10-01    3.553841e+06
# 2022-11-01    3.553557e+06
# 2022-12-01    3.553416e+06
# Freq: MS, Name: ARIMA Predictions, dtype: float64

# %%
pred.plot(figsize = (12,5),legend = True)

# %%
gr = data.groupby(['Year','Month','Which_Place_in_India?']).agg({'How_many_Landed_on_the_our_Page_and_clicked_on_a_button?': sum})
gr
# Out:
#                                   How_many_Landed_on_the_our_Page_and_clicked_on_a_button?
# Year Month Which_Place_in_India?
# 2019 1     Bangalore                                                         616082
#            Chennai                                                           514661
#            Dehradun                                                          730669
#            Indore                                                           4802600
#            Pune                                                             2605342
# ...                                                                             ...
# 2021 12    Bangalore                                                         614093
#            Chennai                                                          2920645
#            Dehradun                                                          728085
#            Indore                                                           7589394
# ...

# %%
gr.unstack()
# Out:
#                       How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# Which_Place_in_India?                                                Bangalore
# Year Month
# 2019 1                                                            616082
#      2                                                            660315
#      3                                                            646352
#      4                                                            600075
#      5                                                            749816
#      6                                                            756389
#      7                                                            669153
#      8                                                            698207
#      9                                                            772817
#      10                                                           777091
# ...

# %%
fig,ax = plt.subplots(figsize = (15,7))
gr.unstack().plot(ax=ax)
plt.show()
